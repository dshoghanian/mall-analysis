# %% [markdown]
# <div>
#     <h1 style="text-align: center; font-size: 24px; font-weight: bold;">
#         California Malls Sales Analysis
#     </h1>
#     <h2 style="text-align: center; font-size: 16px;">
#         By: Dante Shoghanian, Wilson Chatham, Tommy Ropp
#     </h2>
# </div>

# %% [markdown]
# <div style="text-align: center; font-size 18px; font-weight: bold;">
# Executive Summary
# </div>

# %% [markdown]
# This report analyzes sales performance across malls in California to identify the factors that drive higher sales, focusing on customer demographics and mall characteristics. The primary audience for this report includes mall operators and individual store managers looking to optimize their marketing strategies and operational decisions. By pinpointing the qualities that contribute to successful malls, this study aims to provide actionable insights to help increase revenue across the board.
#
# Our report aims to answer four main questions: What are the major performance trends for malls across California, what seasonality or cyclicality is present in shopper behavior, what mall characteristics contribute to increased revenue, and who are the most profitable customer segments and categories.
#
# To address these questions we utilized datasets that include sales data, mall characteristics, and customer demographic information. Our tool of choice was python, utilizing the pandas, matplotlib, and seaborn libraries in order to analyze and visualize our datasets. Our methodology involved cleaning and preprocessing the data, joining the datasets, enhancing the data with additional columns for time series and demographic analysis, segmenting the data by relevant categories, and applying statistical and visual analyses to identify trends and correlations.
#
# We found that there was a large drop off in sales between 2022 and 2023. However, we are attributing this to a lack of data in the dataset as external research showed us that the retail and mall industries are reporting strong numbers. There is also cyclicality present in shopper behavior, with higher sales in the winter months but no discernible patterns on a weekly basis. Through an analysis of mall characteristics, we found that larger malls have higher sales, with greater store frequency having a correlation with higher sales. Finally, amongst shopper demographics, we found females in the 18-28 and 59-69 age groups had the highest sales in the clothing, shoes, and technology categories. Technology also produced the highest priced reciepts over all, followed by shoes and then clothes.
#
# Based on these findings, we recommend that mall operators prioritize marketing, inventory, and staffing efforts during the holiday season to capitalize on peak shopper activity. We also recommend exploring opportunities for expansion and increasing store count due to the correlation with increased sales. For clothing stores, we recommend catering to women in the 18-28 and 59-69 age groups and for technology stores we recommend focusing marketing efforts on men and women over the age of 28, offering continued technical support to promote repeat visits. If these recommendations are followed, we believe that both mall operators and individual stores will maximize their appeal to their core demographics and increase their revenue potential.
#
# Ultimately, this report highlights the importance of aligning mall operations and store offerings with the preferences of target customers. By leveraging these insights, California malls can position themselves as attractive destinations for shoppers, driving growth and success in a competitive retail market.

# %% [markdown]
# <div style="text-align: center; font-size 18px; font-weight: bold;">
# Introduction
# </div>

# %% [markdown]
# Malls play a crucial role in the retail landscape of California, serving diverse communities and offering a range of shopping, dining, and entertainment options. With the challenges of maintaining foot traffic and maximizing profitability in an increasingly competitive market, understanding customer behavior and mall characteristics is critical. As consumer preferences and shopping habits evolve, malls must adapt to remain relevant and profitable. This study will help malls across California identify and leverage their strengths to better meet the needs of their target audiences, ultimately driving increased sales and long-term success.
# By examining multiple datasets that include sales figures, mall characteristics, and customer demographics, we aim to identify the qualities that drive sales performance. This analysis will provide actionable and data-driven insights for mall operators to better position their marketing strategies and for individual stores to tailor their offerings to specific customer segments. These insights can also help malls attract their target audiences and promote a more efficient tenant mix to ensure customers needs are being met.
# This report stands out because it combines datasets including sales, customer demographics, and mall characteristics to provide a comprehensive analysis of what drives success in the mall ecosystem. Rather than relying on generalized trends, this report focuses specifically on California malls, tailoring the findings to the unique attributes of the state’s diverse customer base and retail environment. By focusing our efforts on a more niche market, we are able to provide richer insights more tailored to our target communities.
# Our report seeks to answer the following questions:
#
# <strong>
# 1. What are the overall trends for malls in California
# </strong>
#
# Understanding the overall trends for malls in California provides a foundational context for our analysis and establishes a comprehensive overview of the retail landscape in the state. This information enables mall operators and store managers to better understand the broader environment in which they operate.
#
# <strong>
# 2. What seasonality/cyclicality is present in shopper behavior
# </strong>
#
# Understanding seasonal and cyclical trends in shopper behavior reveals patterns in revenue and foot traffic across different time frames, such as months, quarters, and days of the week. These insights enable businesses to align marketing strategies, inventory planning, and promotions with periods of peak shopper activity. By leveraging these trends, companies can optimize operations and improve customer engagement throughout the year.
#
# <strong>
# 3. What mall characteristics contribute to increased revenue
# </strong>
#
# Determining the impact of characteristics such as size, store count, and age of malls on overall revenue is crucial in determining how to best maximize revenues. These insights are crucial to providing greater context to customer interests, such as the impact on size and varieties of stores on revenue.
#
# <strong>
# 4. Who are the most profitable customer segments and categories
# </strong>
#
# Identifying the most profitable customer segments and product categories is essential for maximizing revenue and optimizing resource allocation. This insight enables mall operators and individual stores to focus their marketing efforts, product offerings, and customer service strategies on the groups and categories that contribute the most to their bottom line.

# %% [markdown]
# <div style="text-align: center; font-size 18px; font-weight: bold;">
# Methodology
# </div>

# %% [markdown]
# During our analysis we used Python in a Jupyter Notebook environment. The three datasets included customer demographics and behavior, transaction and revenue data, and mall characteristics. These datasets were imported using the pandas library and explored with functions such as viewing initial rows, identifying missing values, and checking data structure and types for data quality. After cleaning the datasets, they were merged using a common identifier such as customer IDs and mall name to create a unified dataset that linked customer demographics, sales performance, and mall-specific characteristics. Following the integration, data filtering and segmentation were done which allowed us to focus on specific malls and locations such as those in Southern California. The data aggregation allowed for grouping revenue and shopper trends at monthly, quarterly, and weekly levels to identify seasonal and cyclical trends. The visualizations were done using matplotlib to illustrate trends in revenue, shopping activity, demographic patterns. Finally, the mall characteristics were analyzed to identify their impact on the revenue, such as location, size and type. This approach provided a comprehensive review of shopper behavior and mall performance.

# %% [markdown]
# <div style="text-align: center; font-size 18px; font-weight: bold;">
# Findings
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

customer_df = pd.read_excel('customer_data.xlsx')
sales_df = pd.read_excel('sales_data.xlsx')
mall_df = pd.read_excel('shopping_mall_data.xlsx')

# %%
customer_df.head()
# Out:
#   customer_id  gender   age payment_method
# 0     C241288  Female  28.0    Credit Card
# 1     C111565    Male  21.0     Debit Card
# 2     C266599    Male  20.0           Cash
# 3     C988172  Female  66.0    Credit Card
# 4     C189076  Female  53.0           Cash

# %%
sales_df.head()
# Out:
#   invoice_no customer_id  category  quantity invoice date    price  \
# 0    I138884     C241288  Clothing         5   05/08/2022  1500.40
# 1    I317333     C111565     Shoes         3   12/12/2021  1800.51
# 2    I127801     C266599  Clothing         1   09/11/2021   300.08
# 3    I173702     C988172     Shoes         5   05/16/2021  3000.85
# 4    I337046     C189076     Books         4   10/24/2021    60.60
#
#               shopping_mall
# 0         South Coast Plaza
# 1            Beverly Center
# 2    Westfield Century City
# 3  Stanford Shopping Center
# 4         South Coast Plaza

# %%
mall_df.head()
# Out:
#             shopping_mall  construction_year  area (sqm)     location  \
# 0       South Coast Plaza               1967      250000   Costa Mesa
# 1   Westfield Valley Fair               1986      220000  Santa Clara
# 2               The Grove               2002       56000  Los Angeles
# 3  Westfield Century City               1964      133000  Los Angeles
# 4          Beverly Center               1982      111000  Los Angeles
#
#    store_count
# 0          270
# 1          230
# 2          140
# 3          200
# 4          160

# %% [markdown]
# To begin with, we loaded in our three datasets and looked at the first five rows in order to get a better idea of what the data could tell us. We pinpointed shared columns that we could merge on and any interesting trends we could find at first glance. Noticing that our customer and sales dataframes shared customer_id columns and our sales and malls dataframes shared shopping_mall columns, we decided to merge them together.

# %%
cust_sales_df = pd.merge(customer_df,sales_df, on='customer_id')
cust_sales_df.head()
cust_sales_malls_df = pd.merge(cust_sales_df, mall_df, on='shopping_mall')
cust_sales_malls_df.head(20)
cust_sales_malls_df.set_index('customer_id', inplace=True)
cust_sales_malls_df['sale'] = cust_sales_malls_df['price'] * cust_sales_malls_df['quantity']
cust_sales_malls_df['sale']
cust_sales_malls_df.head()
cust_sales_malls_df.index.nunique()
cust_sales_malls_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94466 entries, C241288 to C273973
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             94466 non-null  object
#  1   age                94349 non-null  float64
#  2   payment_method     94466 non-null  object
#  3   invoice_no         94466 non-null  object
#  4   category           94466 non-null  object
#  5   quantity           94466 non-null  int64
#  6   invoice date       94466 non-null  object
#  7   price              94466 non-null  float64
#  8   shopping_mall      94466 non-null  object
#  9   construction_year  94466 non-null  int64
#  10  area (sqm)         94466 non-null  int64
#  11  location           94466 non-null  object
#  12  store_count        94466 non-null  int64
#  13  sale               94466 non-null  float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 12.8+ MB

# %% [markdown]
# After merging the data we noticed that there was a price and a quantity column, leading us to the realization that we needed a total sale revenue column in order to see how much was purchased in total during a single trip. Another observation we had at this point was the fact that there were no repeat customer_id's. This meant that customer records were not kept, just sales records from each purchase. This altered our original thought process of analyzing individual customers to analyzing customer profiles. After merging the data and getting an understanding of how it was structured, we decided to look at our first question.

# %% [markdown]
# <div style="text-align: center; font-size 12px; font-weight: bold;">
# What are the overall trends for malls in California
# </div>

# %% [markdown]
# The overall trend we decided to focus on was sales over the course of the last three years. Our intital hypothesis was that we would see a downward trend in sales over the course of the three years that the datasets covered. In order to more clearly visualize this, we needed to add month and year columns to our dataset.

# %%
cust_sales_malls_df['invoice date'] = pd.to_datetime(cust_sales_malls_df['invoice date'])
cust_month = cust_sales_malls_df.loc[cust_sales_malls_df['invoice date'].dt.month == 1,:]
months = {1:"January",2:"February",3:"March",4:"April",5:"May",6:"June",7:"July",
          8:"August",9:"September",10:"October",11:"November",12:"December"}
month = []
for i in range(1,13):
  month.append(months[i])
month
cust_sales_malls_df['month_of_sale'] = cust_sales_malls_df['invoice date'].dt.month.map(months)

# %%
years = {2021: 21, 2022: 22, 2023: 23}
cust_sales_malls_df['year'] = cust_sales_malls_df['invoice date'].dt.year.map(years)
print("2023 Customer Frequency\n")
print(cust_sales_malls_df.loc[cust_sales_malls_df['year'] == 23,:]['shopping_mall'].value_counts())
print("\n2022 Customer Frequency\n")
print(cust_sales_malls_df.loc[cust_sales_malls_df['year'] == 22,:]['shopping_mall'].value_counts())
print("\n2021 Customer Frequency\n")
print(cust_sales_malls_df.loc[cust_sales_malls_df['year'] == 21,:]['shopping_mall'].value_counts())
# Out:
# 2023 Customer Frequency
#
# shopping_mall
# South Coast Plaza           1724
# Del Amo Fashion Center      1715
# Westfield Century City      1265
# Stanford Shopping Center     869
# Westfield Valley Fair        841
# Fashion Valley               464
# The Grove                    430
# Beverly Center               413
# Glendale Galleria            408
# Name: count, dtype: int64
#
# 2022 Customer Frequency
#
# shopping_mall
# Del Amo Fashion Center      9202
# South Coast Plaza           9153
# Westfield Century City      6890
# Stanford Shopping Center    4613
# Westfield Valley Fair       4521
# Beverly Center              2281
# Fashion Valley              2281
# Glendale Galleria           2220
# The Grove                   2159
# Name: count, dtype: int64
#
# 2021 Customer Frequency
#
# shopping_mall
# Del Amo Fashion Center      9026
# South Coast Plaza           8946
# Westfield Century City      6856
# Stanford Shopping Center    4679
# Westfield Valley Fair       4419
# ...

# %% [markdown]
# When adding our year column, we decided to take a look at shopper frequency across the years. We noticed a strange pattern where shopper frequency looked regular in 2021 and 2022 but had a steep drop off in 2023. In order to look at this on a mall by mall basis we seperated each mall into it's own dataframe in a dictionary and looked at different columns to compare between the years.

# %%
mall_dataframes = {}
cust_sales_malls_df[cust_sales_malls_df.year == 22]['shopping_mall'].value_counts()
cust_sales_malls_df[cust_sales_malls_df.year == 23]['shopping_mall'].value_counts()
for i in cust_sales_malls_df['shopping_mall'].unique():
  mall_dataframes[i] = cust_sales_malls_df[cust_sales_malls_df['shopping_mall'] == i]
plt.plot(mall_dataframes['Beverly Center'][cust_sales_malls_df.year == 23].groupby('month_of_sale')['sale'].sum(), label="2023")
plt.plot(mall_dataframes['Beverly Center'][cust_sales_malls_df.year == 22].groupby('month_of_sale')['sale'].sum(), label="2022")
plt.xticks(rotation=45)
plt.title('Total Revenue for Beverley Center 2022 vs. 2023')
plt.ylabel('Total Revenue')
plt.legend()
print(mall_dataframes['Beverly Center'][cust_sales_malls_df.year == 23]['category'].value_counts())
print(mall_dataframes['Beverly Center'][cust_sales_malls_df.year == 22]['category'].value_counts())
print(mall_dataframes['Beverly Center'][cust_sales_malls_df.year == 22]['payment_method'].value_counts())
print(mall_dataframes['Beverly Center'][cust_sales_malls_df.year == 23]['payment_method'].value_counts())
print(mall_dataframes['Beverly Center'][cust_sales_malls_df.year == 22]['shopping_mall'].value_counts())
# Out:
# category
# Clothing           144
# Cosmetics           66
# Food & Beverage     64
# Toys                47
# Shoes               34
# Books               23
# Souvenir            21
# Technology          14
# Name: count, dtype: int64
# category
# Clothing           800
# Cosmetics          356
# Food & Beverage    320
# Toys               230
# Shoes              207
# Souvenir           138
# Books              119
# Technology         111
# Name: count, dtype: int64
# payment_method
# Cash           991
# Credit Card    826
# Debit Card     464
# Name: count, dtype: int64
# payment_method
# Cash           195
# Credit Card    136
# Debit Card      82
# Name: count, dtype: int64
# shopping_mall
# Beverly Center    2281
# Name: count, dtype: int64
# C:\Users\dshog\AppData\Local\Temp\ipykernel_31420\2816414881.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %% [markdown]
# After looking at frequency's and visualizing sales for the Beverley Center, we could see that this trend was present across the data. In order to get a better idea of the severity of the drop off, we decided to plot the data across the three years on the same graph.

# %%
abvs = {"January":"Jan","February":"Feb","March":"Mar","April":"Apr","May":"May","June":"Jun",
        "July":"Jul","August":"Aug","September":"Sep","October":"Oct","November":"Nov","December":"Dec"}
ordered_monyear = ['Jan 21', 'Feb 21', 'Mar 21', 'Apr 21', 'May 21', 'Jun 21', 'Jul 21', 'Aug 21', 'Sep 21', 'Oct 21', 'Nov 21', 'Dec 21',
           'Jan 22', 'Feb 22', 'Mar 22', 'Apr 22', 'May 22', 'Jun 22', 'Jul 22', 'Aug 22', 'Sep 22', 'Oct 22', 'Nov 22', 'Dec 22',
           'Jan 23', 'Feb 23', 'Mar 23', 'Apr 23', 'May 23', 'Jun 23', 'Jul 23', 'Aug 23', 'Sep 23', 'Oct 23', 'Nov 23', 'Dec 23']
cust_sales_malls_df['abvs'] = cust_sales_malls_df['month_of_sale'].map(abvs)
cust_sales_malls_df['monthyear'] = cust_sales_malls_df['abvs'] + " " + cust_sales_malls_df['year'].astype(str)
timeseries = cust_sales_malls_df.groupby('monthyear')['sale'].sum().reset_index()
timeseries['monthyear'] = pd.Categorical(timeseries['monthyear'], categories=ordered_monyear, ordered=True)
timeseries.sort_values(by='monthyear', inplace=True)
fig, ax3 = plt.subplots()
ax3.plot(timeseries['monthyear'], timeseries['sale'])
ax3.set_xticklabels(labels=timeseries['monthyear'],rotation=90)
ax3.set_ylabel('Total Revenue (in tens of millions)')
ax3.set_title('Total Revenue for California Malls 2021 - 2023')
# Out:
# C:\Users\dshog\AppData\Local\Temp\ipykernel_31420\3690665754.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax3.set_xticklabels(labels=timeseries['monthyear'],rotation=90)
# Text(0.5, 1.0, 'Total Revenue for California Malls 2021 - 2023')

# %% [markdown]
# This graph shows how drastic the drop off in sales was from 2022 to 2023. At this point we weren't sure if this was simply due to a lack of data in the dataset or if this was a real trend in the shopping mall industry. To ensure this trend wasn't occuring due to a just a few malls, we decided to plot each of the malls across the three years.

# %%
fig, ax4 = plt.subplots(5,2)
malls = list(cust_sales_malls_df['shopping_mall'].unique())
for i in cust_sales_malls_df['shopping_mall'].unique():
  mall_dataframes[i] = cust_sales_malls_df[cust_sales_malls_df['shopping_mall'] == i]
for mall in malls:
  df = mall_dataframes[mall]
  name = df.iloc[0,8]
  df = df.groupby('monthyear')['sale'].sum().reset_index()
  df['monthyear'] = pd.Categorical(df['monthyear'], categories=ordered_monyear, ordered=True)
  df.sort_values(by='monthyear', inplace=True)
  plt.ylabel('Total Revenue (in tens of millions)')
  plt.plot(df['monthyear'],df['sale'],label=name)
  plt.legend(prop={'size':6})
plt.xticks(ticks=ordered_monyear,rotation=90)
plt.title('Total Revenue by Mall in California 2021 - 2023')
# Out:
# Text(0.5, 1.0, 'Total Revenue by Mall in California 2021 - 2023')

# %% [markdown]
# Here we see that this trend is present across all shopping malls in the dataset. In our interpretations section we will cover the external research we did in order to cross refrence this trend and how we decided to understand our findings. After our initial exploratory analysis, we decided to dive deeper into our sales data in order to uncover the trends in shopper behavior.

# %% [markdown]
# <div style="text-align: center; font-size 12px; font-weight: bold;">
# What seasonality/cyclicality is present in shopper behavior
# </div>

# %%
monthly_sales = cust_sales_malls_df.groupby('month_of_sale')['sale'].sum().reset_index()
fig, ax = plt.subplots(2,1)
monthly_sales['month_of_sale'] = pd.Categorical(monthly_sales['month_of_sale'],categories=month,ordered=True)
monthly_sales.sort_values(by='month_of_sale', inplace=True)
ax[1].bar(monthly_sales['month_of_sale'],monthly_sales['sale'])
ax[0].plot(monthly_sales['month_of_sale'],monthly_sales['sale'])
ax[0].set_xticklabels(labels=[])
ax[0].set_ylabel('Revenue (in tens of millions)')
ax[1].set_xticklabels(labels=monthly_sales['month_of_sale'],rotation=45)
ax[1].set_ylabel('Revenue (in tens of millions)')
ax[0].set_title('Revenue by Month')
# Out:
# C:\Users\dshog\AppData\Local\Temp\ipykernel_31420\2650523175.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(labels=monthly_sales['month_of_sale'],rotation=45)
# Text(0.5, 1.0, 'Revenue by Month')

# %% [markdown]
# The revenue trends show a decline after January, possibly due to post holiday reduced spending. The pattern reflects peak in months of November and December (holiday season). Reduced shopping in months January - March as people recover from holiday spending

# %%
seasons = {"January":"Winter","February":"Winter","March":"Spring","April":"Spring","May":"Spring","June":"Summer","July":"Summer",
          "August":"Summer","September":"Fall","October":"Fall","November":"Fall","December":"Winter"}
cust_sales_malls_df['seasons'] = cust_sales_malls_df['month_of_sale'].map(seasons)
seasons_sorted = ['Winter','Spring','Summer','Fall']
seasonal_sales = cust_sales_malls_df.groupby('seasons')['sale'].sum().reset_index()
seasonal_sales
seasonal_sales['seasons'] = pd.Categorical(seasonal_sales['seasons'],categories=seasons_sorted,ordered=True)
seasonal_sales.sort_values(by='seasons',inplace=True)
fig, ax2 = plt.subplots(2,1)
ax2[0].plot(seasonal_sales['seasons'],seasonal_sales['sale'])
ax2[1].bar(seasonal_sales['seasons'],seasonal_sales['sale'])
ax2[0].set_ylabel('Revenue (in tens of millions)')
ax2[1].set_ylabel('Revenue (in tens of millions)')
# Out:
# Text(0, 0.5, 'Revenue (in tens of millions)')

# %% [markdown]
# Winter (December - February) shows the highest activity, aligning with the holiday season. A gradual decline in spring and summer suggests reduced shopping intensity. Fall shows a slight increase as the holiday season begins.

# %%
sales_df['invoice date'] = pd.to_datetime(sales_df['invoice date'])
sales_df['day_of_week'] = sales_df['invoice date'].dt.day_name()
shoppers_by_day = sales_df.groupby('day_of_week').size().reset_index(name='shopper_count')
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
shoppers_by_day['day_of_week'] = pd.Categorical(shoppers_by_day['day_of_week'], categories=days_order, ordered=True)
shoppers_by_day.sort_values('day_of_week', inplace=True)



plt.bar(shoppers_by_day['day_of_week'], shoppers_by_day['shopper_count'], color='skyblue')
plt.title('Shoppers Count by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Shoppers')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Shopping activity is generally consistent across weekdays (Monday - Friday). Weekends (Saturday and Sunday) see similar or slightly lower shopper counts compared to the weekdays. Possibly due to leisure-oriented shopping trips.

# %%
all_malls_data = sales_df.groupby(['shopping_mall', 'day_of_week']).size().reset_index(name='shopper_count')
all_malls_data['day_of_week'] = pd.Categorical(all_malls_data['day_of_week'], categories=days_order, ordered=True)
pivot_data = all_malls_data.pivot(index='day_of_week', columns='shopping_mall', values='shopper_count').fillna(0)
pivot_data.plot(kind='bar', figsize=(12, 7), width=0.8)
plt.title('Shoppers Count by Day of the Week for All Malls')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Shoppers')
plt.xticks(rotation=45)
plt.legend(title='Shopping Mall', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Malls like South Coast Plaza and Beverly Center show consistent shopper counts throughout the week, with no clear weekend spike. Smaller malls like The Grove or Fashion Valley might have slightly reduced weekday activity

# %% [markdown]
# <div style="text-align: center; font-size 12px; font-weight: bold;">
# What mall characteristics contribute to increased revenue
# </div>

# %%
mall_summary = cust_sales_malls_df.groupby('shopping_mall').agg(
    total_revenue=('sale', 'sum'),
    avg_purchase_price=('sale', 'mean'),
    store_count=('store_count', 'mean'),
    mall_size=('area (sqm)', 'mean'),
    mall_age=('construction_year', lambda x: 2024 - x.mean())
).reset_index()

# %%
plt.scatter(mall_summary['mall_size'], mall_summary['total_revenue'], color='b', alpha=0.6)
plt.title('Mall Size vs. Total Revenue')
plt.xlabel('Mall Size (sqm)')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# In this chart we can see there is a trend of larger Total Revenue correlated with larger Mall size.

# %%
plt.scatter(mall_summary['store_count'], mall_summary['total_revenue'], color='b', alpha=0.6)
plt.title('Store Count vs. Total Revenue')
plt.xlabel('Store Count')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# In this chart we can see there is a trend of larger Total Revenue correlated with larger Store Counts.

# %%
plt.scatter(mall_summary['mall_age'], mall_summary['total_revenue'], color='b', alpha=0.6)
plt.title('Mall Age vs. Total Revenue')
plt.xlabel('Mall Age (Years)')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# In this chart we can see there is a trend of larger Total Revenue correlated with older malls.

# %%
plt.scatter(mall_summary['mall_age'], mall_summary['mall_size'], label='Mall Size', color='blue', alpha=0.6)
plt.xlabel('Mall Age (Years)')
plt.ylabel('Mall Size (sqm)')
plt.title('Mall Age vs. Mall Size')
plt.show()

# %% [markdown]
# We can see in this chart that older malls tend to also be larger in size.

# %%
category_mall_stats = cust_sales_malls_df.groupby(['shopping_mall', 'category'])['sale'].sum().reset_index()
pivot_data = category_mall_stats.pivot(index='shopping_mall', columns='category', values='sale')
category_medians = cust_sales_malls_df.groupby('category')['sale'].median()
pivot_data = pivot_data.apply(lambda col: col.fillna(category_medians[col.name]), axis=0)
categories = cust_sales_malls_df['category'].unique()
category_colors = sns.color_palette('tab10', len(categories))
pivot_data.plot(kind='bar',stacked=True,figsize=(12, 6),color=category_colors, alpha=0.85)
plt.title('Total Revenue by Category Across Malls', fontsize=16)
plt.xlabel('Shopping Mall')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Category', loc='upper left')
plt.show()

# %% [markdown]
# This chart shows that the percentage of Total Revenue by Category is consistent across malls. Clothing, Shoes, and Technology comprise the majority of Total Revenue.

# %%
cust_sales_malls_df['age'].describe()
bins=[18,28,38,48,58,69]
labels=['18-28','29-38','39-48','49-58','59-69']
cust_sales_malls_df['age_group'] = pd.cut(cust_sales_malls_df['age'],bins=bins,labels=labels,right=True,include_lowest=True)
gender_age_mall = cust_sales_malls_df.groupby(['shopping_mall', 'gender', 'age_group']).size().reset_index(name='count')
gender_age_mall = gender_age_mall.dropna(subset=['gender', 'age_group'])
pivot_data = gender_age_mall.pivot_table(index='shopping_mall', columns=['gender', 'age_group'], values='count')
malls = pivot_data.index
age_ranges = cust_sales_malls_df['age_group'].unique()
bar_width = 0.4
x = np.arange(len(malls))
gender_colors = {'Male': 'lightblue', 'Female': 'lightcoral'}
fig, ax = plt.subplots(figsize=(12, 8))
genders = ['Male','Female']
for i, gender in enumerate(genders):
    bottom = np.zeros(len(malls)) 
    for age_group in age_ranges:
        age_counts = pivot_data[(gender, age_group)].values if (gender, age_group) in pivot_data.columns else np.zeros(len(malls))
        bars = ax.bar(x + (i * bar_width), age_counts, bar_width, color=gender_colors[gender], edgecolor='white', bottom=bottom)
        for bar, count in zip(bars, age_counts):
            if count > 0:
                ax.text(bar.get_x() + bar.get_width() / 2, bar.get_y() + bar.get_height() / 2,str(age_group), ha='center', va='center', fontsize=8, color='black')
        bottom += age_counts
ax.set_xticks(x + bar_width / 2)
ax.set_xlabel('Shopping Mall')
ax.set_ylabel('Shoppers')
ax.set_xticklabels(malls, rotation=45, ha='right')
ax.set_title('Gender and Age Range Distribution Across Malls')
ax.legend([plt.Rectangle((0, 0), 1, 1, color=gender_colors[g]) for g in genders], genders, title='Gender', loc='upper left')
plt.show()
# Out:
# C:\Users\dshog\AppData\Local\Temp\ipykernel_31420\1865635606.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gender_age_mall = cust_sales_malls_df.groupby(['shopping_mall', 'gender', 'age_group']).size().reset_index(name='count')
# C:\Users\dshog\AppData\Local\Temp\ipykernel_31420\1865635606.py:8: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_data = gender_age_mall.pivot_table(index='shopping_mall', columns=['gender', 'age_group'], values='count')

# %% [markdown]
# We can see in this chart that the breakdown of gender and age of shoppers is very consistent across malls.

# %% [markdown]
# <div style="text-align: center; font-size 12px; font-weight: bold;">
# Who are the most profitable customer segments and categories
# </div>

# %%
category_sales = cust_sales_malls_df.groupby('category')['sale'].sum().reset_index()
category_sales.sort_values(by='sale', ascending=False, inplace=True)
plt.bar(category_sales['category'],category_sales['sale'])
plt.xticks(ticks=category_sales['category'],rotation=45)
plt.title('Total Revenue by Category')
plt.ylabel('Total Revenue (in millions)')
# Out:
# Text(0, 0.5, 'Total Revenue (in millions)')

# %% [markdown]
# Here we see our highest selling categories across all malls. Clothing, shoes, and technology have commanding leads over all other categories. This gives us insights into customer shopping prefrences that could inform malls on the amount of stores they should have in each category based on historical sales figures.

# %%
age_sales = cust_sales_malls_df.groupby('age_group')['sale'].sum().reset_index()
age_sales.sort_values('sale',ascending=False,inplace=True)
plt.bar(age_sales['age_group'],age_sales['sale'])
plt.title('Total Revenue by Age Group')
plt.ylabel('Total Revenue (in millions)')
plt.xlabel('Age Groups')
age_category_sales = cust_sales_malls_df.groupby(['category','age_group'])['sale'].sum().reset_index()
age_category_sales['category'].unique()
# Out:
# C:\Users\dshog\AppData\Local\Temp\ipykernel_31420\370629464.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_sales = cust_sales_malls_df.groupby('age_group')['sale'].sum().reset_index()
# C:\Users\dshog\AppData\Local\Temp\ipykernel_31420\370629464.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_category_sales = cust_sales_malls_df.groupby(['category','age_group'])['sale'].sum().reset_index()
# array(['Books', 'Clothing', 'Cosmetics', 'Food & Beverage', 'Shoes',
#        'Souvenir', 'Technology', 'Toys'], dtype=object)

# %% [markdown]
# Looking at our data we see that there isn't a major difference between age groups in terms of total sales. The difference between the top revenue age group and bottom is less than half a million. We do see two groups that lead the pack however, those being 18-28 and 59-69. These could be core demographics for marketing efforts to focus on. It does seem that all age groups are vital to focus on as the margins between the top and bottom groups are slim.

# %%
pivot_table = pd.pivot_table(cust_sales_malls_df,values='sale',
                             index=['gender','age_group'],
                             columns='category',
                             aggfunc='sum')
pivot_table
plt.figure(figsize=(10,6))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap="Blues")
plt.title('Sales by Gender and Age Group per Product Category')
plt.ylabel('Gender and Age Group')
plt.xlabel('Product Category')
plt.show()
# Out:
# C:\Users\dshog\AppData\Local\Temp\ipykernel_31420\652630907.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = pd.pivot_table(cust_sales_malls_df,values='sale',

# %% [markdown]
# Here we split up our customers further by both age group and gender. This way we see who our most profitable customer profiles are in terms of demographics. We see that females overall have an edge on males, as well as the top categories we saw in our categories graph. Females in the 18-28 and 59-69 age groups looking to buy clothing could be a key demographic to focus on.

# %%
cust_sales_malls_df['sale'].describe()
top_custs = cust_sales_malls_df[cust_sales_malls_df.sale >=2700]
low_custs = cust_sales_malls_df[cust_sales_malls_df.sale < 2700]
total_low = low_custs.sale.sum()
total_top = top_custs.sale.sum()
print(f'Total sales for bottom 75% customers: {total_low} \nTotal sales for top 25% customers: {total_top}')
# Out:
# Total sales for bottom 75% customers: 29093677.05
# Total sales for top 25% customers: 209766979.0

# %% [markdown]
# Another way of categorizing customers is in terms of the most valuable trips. Here we cut our data based on our top quartiles. We see that total sales for our top 25% of customer trips creates 10x more revenue than the bottom 75%.

# %%
plt.bar(top_custs['category'],top_custs['sale'], label='Top 25%')
plt.bar(low_custs['category'],low_custs['sale'], label="Bottom 75%")
plt.xticks(rotation=45)
plt.xlabel("Revenue (in Thousands)")
plt.ylabel("Category")
plt.title("Category Sales for Top 25% vs. Bottom 75% Receipts")
plt.legend()
plt.show()

# %% [markdown]
# Here we see our highest price trips go for technology, shoes, and then clothing. These three categories are the same as our top selling categories. However, here technology has the highest total ticket prices when compared to the other two categories. These could be products to focus on when stores are trying to maximize revenue and attract the most valuable customers.

# %% [markdown]
# <div style="text-align: center; font-size 18px; font-weight: bold;">
# Interpretation
# </div>

# %% [markdown]
# <div style="text-align: center; font-size 12px; font-weight: bold;">
# What are the overall trends for malls in California
# </div>

# %% [markdown]
# Based solely on our data, it appears that malls in California took a major hit in terms of shopper frequency annd total revenue in 2023. However, it is our belief that this drop off was created due to a limitation in the data. Perhaps figures for the rest of 2023 were under reported because of some error on the data collectors part or some other problem in the data pipeline. The exact cause of this problem is unknown due to the variety of sources that the data was collected from and the nature of the documentation. Based on external research, we believe that the mall industry remained equivalent or surpassed previous years in terms of performance (NAIGlobal, 2023). Several outside sources relay that Gen Z has been strengthing malls presence in the retail industry across America (Jasinki, 2024).
#
# If the trend present in our data is in fact the reality of the situation, there could be a few reasons for this. The major issue we see in 2023 in the retail industry is consumers tightening their budgets. Inflation took a hit on commerce across the country and our drop off could be reflecting this fact (Statista, 2024). Another reason we may be seeing this is pull back from the reopening of public places after COVID. People flocked to gathering spaces like malls, concerts, and travel destinations after COVID restrctions subsided. However, a few years on from this and it seems that demand is beginning to normalize again, something that our data could be reflecting (Hickey, 2023). Ultimately, we suspect our assumption that this trend is simply due to a lack of data is the reality of the situation.

# %% [markdown]
# <div style="text-align: center; font-size 12px; font-weight: bold;">
# What seasonality/cyclicality is present in shopper behavior
# </div>

# %% [markdown]
# Our analysis highlights key seasonal and cyclical trends in shopper behaviors. Monthly and quarterly seasonality show peak activity in November and December due to the holiday season, followed by a decline in January through March as shoppers recover from holiday spending. Fall brings a slight uptick in activity as the holiday season approaches. The weekly trends suggest consistent traffic during the weekdays (Monday-Friday), with slightly lower activity on the weekends possibly due to leisure-oriented shopping trips, revealing opportunities for targeted weekend promotions. The mall specific trends indicate that larger malls such as South Coast Plaza and Del Amo Fashion Center sustain consistent traffic throughout the week, in comparison to smaller malls like The Grove see reduction in weekday activity.

# %% [markdown]
# <div style="text-align: center; font-size 12px; font-weight: bold;">
# What mall characteristics contribute to increased revenue
# </div>

# %% [markdown]
# Our data reveals a trend indicating that larger total revenue is correlated with larger mall sizes, higher store counts, and older malls. However, because older malls also tend to be larger and have more stores, we eliminated mall age as a deciding variable. The rationale is that bigger malls with more stores can attract larger volumes of shoppers by offering a greater variety of products and more opportunities for purchases. Other factors, such as shopper demographics and product offerings, remain consistent across all malls. Notably, women are more frequent shoppers than men, and the categories of Clothing, Shoes, and Technology account for the majority of total revenue.
#
# These trends suggest that larger malls with more stores have a significant advantage. While these findings may be valuable for planning new mall developments or renovating and expanding existing ones, many malls may not have the option to increase their size or store count. For malls unable to expand, the most actionable insight is to optimize their ability to meet demand in the key categories of Clothing, Shoes, and Technology while tailoring their offerings more heavily toward women shoppers. This strategy provides the best opportunity to capitalize on consistent trends across all malls.

# %% [markdown]
# <div style="text-align: center; font-size 12px; font-weight: bold;">
# Who are the most profitable customer segments and categories
# </div>

# %% [markdown]
# Looking at our data, we see that clothing by far is the highest selling category. However, this doesn't show the full story. Splitting our data up into profiles based on demographics like age and gender, we see that female's between 18-28 and 59-69 are significantly contributing to this demand for clothing. If we take a look at our highest ticket price trips, we see that clothing is actually third to shoes and technology. Technology seems to once again sell best to females in malls however, age groups above 18-28 seem more likely to buy these more expensive products.
#
# Through our slicing of the data, we see that marketing efforts by stores and malls must be carefully positioned to their respective target demographics. For malls looking to attract the highest value customers, they should focus on technology advertisements and offers to males and females ages 28 and older. Perhaps this demographic feels more comfortable buying technology in person rather than online. When it comes to clothing, malls should focus on stores that cater to woman, specifically those in the older demographic of 59-69 and those in the younger demographic of 18-28. All other store decisions in terms of products that should be sold and the number of stores that should be opened in each category should be based on customer frequency and sales within those categories.

# %% [markdown]
# <div style="text-align: center; font-size 18px; font-weight: bold;">
# Recommendations
# </div>

# %% [markdown]
# 1. Prioritize marketing, inventory, and staffing efforts during the holiday season to capitalize on peak shopper activity
#
# 2. Explore opportunities for expansion and increasing store count.
#
# 3. Cater clothing stores to women in the 18-28 and 59-69 age groups
#
# 4. Focus marketing efforts for technology on men and women over the age of 28, offering continued technical support to promote repeat visits.

# %% [markdown]
# <div style="text-align: center; font-size 18px; font-weight: bold;">
# Conclusion
# </div>

# %% [markdown]
# This report provides a detailed analysis of factors influencing sales performance across California malls, focusing on shopper demographics, mall characteristics, and seasonal trends. While the 2023 data indicates a sharp decline in revenue, this appears to be due to incomplete reporting rather than actual performance issues. External research shows that malls have experienced strong year-over-year growth, driven by a resurgence in multi-stop excursions that combine retail, dining, and entertainment. These findings emphasize the importance of understanding and adapting to evolving shopper behaviors.
#
# Our analysis highlights several key trends and actionable insights. First, holiday months represent the highest revenue periods, underscoring the importance of prioritizing marketing, inventory, and staffing efforts during this peak season. Larger malls with higher store counts consistently outperformed smaller ones, suggesting that expansion and diversification of offerings can drive increased shopper traffic and revenue where feasible.
#
# Demographic analysis revealed that clothing stores see the greatest success with women aged 18–28 and 59–69, while technology stores perform best with men and women over 28. These findings suggest the need to tailor store offerings and marketing strategies to these high-value customer segments. For technology stores, offering continued technical support can encourage repeat visits and drive long-term customer loyalty.
#
# Despite these valuable insights, the analysis faced limitations. The inability to track repeat customers restricted deeper profiling of revenue-driving segments. Additionally, the absence of dining and entertainment revenue in the data prevented a comprehensive assessment of their growing importance in mall performance. Future analyses should incorporate these factors to provide a more holistic understanding of the mall ecosystem.
#
# Ultimately, the trends and recommendations presented in this report position California malls to better meet customer needs, optimize operations, and capitalize on growth opportunities. By focusing on targeted marketing, strategic expansion, and adapting to evolving shopping patterns, malls can remain competitive and drive sustained success in a dynamic retail landscape.

# %% [markdown]
# <div style="text-align: center; font-size 18px; font-weight: bold;">
# Bibliography
# </div>

# %% [markdown]
# California Mall Customer Sales Dataset. (n.d.). Retrieved December 1, 2024, from https://www.kaggle.com/datasets/captaindatasets/istanbul-mall
#
# Global: Impact of inflation on spending 2023. (n.d.). Statista. Retrieved December 1, 2024, from https://www.statista.com/statistics/1440244/impact-of-inflation-on-spending-global/
#
# Hickey, C. & CNN. (2023, November 26). American spending has kept the economy going since the pandemic. They may finally be stopping. | CNN Business. CNN. https://www.cnn.com/2023/11/26/business/consumer-spending-slowdown-dg/index.html
#
# igoleta. (2023, October 30). US Malls Still Firmly Part of the Retail Landscape in 2023. NAI Global. https://www.naiglobal.com/news/us-malls-still-firmly-part-of-the-retail-landscape-in-2023/
#
# Rossen Reports: Gen Z is saving traditional malls. Yes, you read that right! (2024, July 17). KETV. https://www.ketv.com/article/rossen-reports-gen-z-is-saving-traditional-malls/61614518

# %% [markdown]
# <div style="text-align: center; font-size 18px; font-weight: bold;">
# Appendix
# </div>

# %%
for mall in malls:
  df = mall_dataframes[mall]
  df = df[df.year == 23]
  name = df.iloc[0,8]
  df = df.groupby('monthyear')['sale'].sum().reset_index()
  df['monthyear'] = pd.Categorical(df['monthyear'], categories=ordered_monyear[24:], ordered=True)
  df.sort_values(by='monthyear', inplace=True)
  plt.plot(df['monthyear'],df['sale'],label=name)
  plt.legend(prop={'size':6})
plt.xticks(ticks=ordered_monyear[24:],rotation=90)
plt.title('Revenue Drop Off in 2023 for All Malls')
plt.ylabel('Total Revenue (in millions)')

# %%
categories = list(age_category_sales['category'].unique())
for i in categories:
  df = age_category_sales[age_category_sales.category == i]
  plt.plot(df['age_group'],df['sale'], label=i, marker='o')
  plt.legend(loc='lower right',prop={'size': 6})
plt.title('Total Revenue by Age Group by Category')
plt.ylabel('Total Revenue (in millions)')
plt.xlabel('Age Group')

# %%
pivot_table = pd.pivot_table(top_custs,values='sale',
                             index=['gender','age_group'],
                             columns='category',
                             aggfunc='sum')
pivot_table
plt.figure(figsize=(10,6))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap="Blues")
plt.title('Top 25% Sales by Gender and Age Group per Product Category')
plt.ylabel('Gender and Age Group')
plt.xlabel('Product Category')
plt.show()

# %%
top_custs.pivot_table(values='invoice_no',index='payment_method',aggfunc='count')
low_custs.pivot_table(values='invoice_no',index='payment_method',aggfunc='count')
low_cust_cards = len(low_custs[low_custs.payment_method == 'Credit Card']) + len(low_custs[low_custs.payment_method == 'Debit Card'])
low_cust_card_prop = round((low_cust_cards/len(low_custs)), 2)
print(f'Percent of bottom 75% of customers who use credit card: {low_cust_card_prop}')
top_cust_cards = len(top_custs[top_custs.payment_method == 'Credit Card']) + len(top_custs[top_custs.payment_method == 'Debit Card'])
top_cust_card_prop = round((top_cust_cards/len(top_custs)), 2)
print(f'Percent of top 25% of customers who use credit card: {top_cust_card_prop}')
print("No meaningful difference (only a fraction of a percent)")

# %%
#Plot 1: Mall Size vs. Average Purchase Price
plt.scatter(mall_summary['mall_size'], mall_summary['avg_purchase_price'], color='g', alpha=0.6)
plt.title('Mall Size vs. Average Purchase Price')
plt.xlabel('Mall Size (sqm)')
plt.ylabel('Average Purchase Price')
plt.show()

# %%
# Plot 2: Store Count vs. Average Purchase Price
plt.scatter(mall_summary['store_count'], mall_summary['avg_purchase_price'], color='g', alpha=0.6)
plt.title('Store Count vs. Average Purchase Price')
plt.xlabel('Store Count')
plt.ylabel('Average Purchase Price')
plt.show()

# %%
# Plot 3: Mall Age vs. Average Purchase Price
plt.scatter(mall_summary['mall_age'], mall_summary['avg_purchase_price'], color='g', alpha=0.6)
plt.title('Mall Age vs. Average Purchase Price')
plt.xlabel('Mall Age (Years)')
plt.ylabel('Average Purchase Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
